# %% [markdown]
# CONVOLUTION NEURAL NETWORK

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# PART 1 DATA PROCESSING

# %% [markdown]
# PREPROCESSING THE TRAINING SET

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

# %% [markdown]
# PREPROCESSING THE TEST SET

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

# %% [markdown]
# PART 2 - BUILDING THE CNN

# %% [markdown]
# INITIALISING THE CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# CONVOLUTION

# %%
cnn.add(tf.keras.layers.Conv2D(filter=32, kernel=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# POOLING

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ADDING A SECOND CONVOLUTIONAL LAYER

# %%
cnn.add(tf.keras.layers.Conv2D(filter=32, kernel=3, activation='relu'))
cnn.add(tf.keras.layer.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# FLATTENING

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# FULLY CONNECTION

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# OUTPUT LAYER

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# PART - 3

# %% [markdown]
# COMPILING THE CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# TRAININNG THE CNN ON THE TRAINING SET AND EVALUATION IT ON THE TEST SET

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)

# %% [markdown]
# PART - 4

# %% [markdown]
# MAKING THE SINGLE PREDICTION

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
print(prediction)
